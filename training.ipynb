# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X_train = pd.read_csv('data/X_train.csv')
y_train = pd.read_csv('data/y_train.csv')

X_test = pd.read_csv('data/X_test.csv')
y_test = pd.read_csv('data/y_test.csv')

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9666666666666667
# d:\tools\programming\python\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 18
#      15 y_pred = knn.predict(X_test)
#      17 print('Accuracy:', accuracy_score(y_test, y_pred))
# ---> 18 print('Precision:', precision_score(y_test, y_pred))
#
# File d:\tools\programming\python\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File d:\tools\programming\python\Lib\site-packages\sklearn\metrics\_classification.py:2634, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2464 @validate_params(
#    2465     {
#    2466         "y_true": ["array-like", "sparse matrix"],
#    (...)   2491     zero_division="warn",
#    2492 ):
#    2493     """Compute the precision.
#    2494
#    2495     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2632     array([0.5, 1. , 1. ])
#    2633     """
# -> 2634     p, _, _, _ = precision_recall_fscore_support(
#    2635         y_true,
#    2636         y_pred,
#    2637         labels=labels,
#    2638         pos_label=pos_label,
#    2639         average=average,
#    2640         warn_for=("precision",),
#    2641         sample_weight=sample_weight,
#    2642         zero_division=zero_division,
#    2643     )
#    2644     return p
#
# File d:\tools\programming\python\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File d:\tools\programming\python\Lib\site-packages\sklearn\metrics\_classification.py:2100, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1929 """Compute precision, recall, F-measure and support for each class.
#    1930
#    1931 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2097  array([2, 2, 2]))
#    2098 """
#    2099 _check_zero_division(zero_division)
# -> 2100 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    2102 # Calculate tp_sum, pred_sum, true_sum ###
#    2103 samplewise = average == "samples"
#
# File d:\tools\programming\python\Lib\site-packages\sklearn\metrics\_classification.py:1881, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1879         if y_type == "multiclass":
#    1880             average_options.remove("samples")
# -> 1881         raise ValueError(
#    1882             "Target is %s but average='binary'. Please "
#    1883             "choose another average setting, one of %r." % (y_type, average_options)
#    1884         )
#    1885 elif pos_label not in (None, 1):
#    1886     warnings.warn(
#    1887         "Note that pos_label (set to %r) is ignored when "
#    1888         "average != 'binary' (got %r). You may use "
#    (...)   1891         UserWarning,
#    1892     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
